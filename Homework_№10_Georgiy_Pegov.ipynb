# %% [markdown]
# # Подготовка df

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
np.random.seed(13)

subjects = ["Mathematics", "Physics", "Chemistry", "Computer Science", "Crafts", "Physical Education"]

grades = ["Satisfactory", "Good", "Excellent"]

df = pd.DataFrame(columns=["id"] + subjects + ["Grade"])

for student_id in range(1, 2002):
    student_data = [student_id]
    for i in range(6):
        score = np.random.randint(0, 100)
        student_data.append(score)
    lab_grade = np.random.choice(grades)
    student_data.append(lab_grade)
    df.loc[len(df)] = student_data

# %%
df.set_index("id", inplace=True)

# %%
le = LabelEncoder()
df['Grade'] = le.fit_transform(df['Grade'])

# %%
df.head()
# Out:
#     Mathematics  Physics  Chemistry  Computer Science  Crafts  \
# id
# 1            82       48         74                16      98
# 2            58       99         26                66      46
# 3            77       74         73                75      52
# 4            19       21         19                11      86
# 5            18       24         28                11      40
#
#     Physical Education  Grade
# id
# 1                   25      2
# 2                   54      1
# 3                    2      2
# 4                   75      1
# 5                   76      0

# %%
df.describe()
# Out:
#        Mathematics      Physics    Chemistry  Computer Science       Crafts  \
# count  2001.000000  2001.000000  2001.000000       2001.000000  2001.000000
# mean     49.244378    49.740130    50.142429         49.754623    49.190905
# std      28.958759    29.108357    28.330870         28.775289    28.682844
# min       0.000000     0.000000     0.000000          0.000000     0.000000
# 25%      24.000000    24.000000    26.000000         25.000000    24.000000
# 50%      50.000000    50.000000    51.000000         49.000000    49.000000
# 75%      75.000000    74.000000    74.000000         76.000000    74.000000
# max      99.000000    99.000000    99.000000         99.000000    99.000000
#
#        Physical Education        Grade
# count         2001.000000  2001.000000
# mean            47.948526     0.980510
# std             29.115268     0.815549
# min              0.000000     0.000000
# 25%             23.000000     0.000000
# 50%             47.000000     1.000000
# 75%             73.000000     2.000000
# max             99.000000     2.000000

# %% [markdown]
# # Подготовка к обучению

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Grade', axis=1), df.Grade, test_size=0.2, random_state=13)

# %%
df.corr().style.background_gradient(cmap="hot_r")
# Out:
# <style type="text/css">
# #T_8f3ca_row0_col0, #T_8f3ca_row1_col1, #T_8f3ca_row2_col2, #T_8f3ca_row3_col3, #T_8f3ca_row4_col4, #T_8f3ca_row5_col5, #T_8f3ca_row6_col6 {
#   background-color: #0b0000;
#   color: #f1f1f1;
# }
# #T_8f3ca_row0_col1, #T_8f3ca_row1_col5, #T_8f3ca_row2_col0 {
#   background-color: #ffffe7;
#   color: #000000;
# }
# #T_8f3ca_row0_col2, #T_8f3ca_row4_col6, #T_8f3ca_row5_col2, #T_8f3ca_row6_col4 {
#   background-color: #ffffc8;
#   color: #000000;
# }
# #T_8f3ca_row0_col3, #T_8f3ca_row0_col6, #T_8f3ca_row3_col2 {
#   background-color: #ffffd4;
#   color: #000000;
# }
# #T_8f3ca_row0_col4 {
#   background-color: #ffffd0;
#   color: #000000;
# }
# #T_8f3ca_row0_col5, #T_8f3ca_row2_col3, #T_8f3ca_row2_col6, #T_8f3ca_row6_col2 {
#   background-color: #ffffd8;
#   color: #000000;
# }
# #T_8f3ca_row1_col0, #T_8f3ca_row2_col1, #T_8f3ca_row2_col4, #T_8f3ca_row4_col2, #T_8f3ca_row5_col6, #T_8f3ca_row6_col3, #T_8f3ca_row6_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_8f3ca_row1_col2, #T_8f3ca_row3_col1, #T_8f3ca_row5_col3, #T_8f3ca_row5_col4, #T_8f3ca_row6_col0 {
#   background-color: #fffff7;
#   color: #000000;
# }
# #T_8f3ca_row1_col3, #T_8f3ca_row4_col3, #T_8f3ca_row4_col5, #T_8f3ca_row5_col1 {
#   background-color: #fffff3;
#   color: #000000;
# }
# #T_8f3ca_row1_col4 {
#   background-color: #ffffe3;
#   color: #000000;
# }
# #T_8f3ca_row1_col6 {
#   background-color: #ffffa0;
#   color: #000000;
# }
# #T_8f3ca_row2_col5 {
#   background-color: #ffffc4;
#   color: #000000;
# }
# #T_8f3ca_row3_col0, #T_8f3ca_row3_col4, #T_8f3ca_row3_col5, #T_8f3ca_row4_col0 {
#   background-color: #ffffef;
#   color: #000000;
# }
# #T_8f3ca_row3_col6, #T_8f3ca_row5_col0 {
#   background-color: #fffffb;
#   color: #000000;
# }
# #T_8f3ca_row4_col1 {
#   background-color: #ffffeb;
#   color: #000000;
# }
# #T_8f3ca_row6_col1 {
#   background-color: #ffffac;
#   color: #000000;
# }
# </style>
# <table id="T_8f3ca" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f3ca_level0_col0" class="col_heading level0 col0" >Mathematics</th>
#       <th id="T_8f3ca_level0_col1" class="col_heading level0 col1" >Physics</th>
#       <th id="T_8f3ca_level0_col2" class="col_heading level0 col2" >Chemistry</th>
#       <th id="T_8f3ca_level0_col3" class="col_heading level0 col3" >Computer Science</th>
#       <th id="T_8f3ca_level0_col4" class="col_heading level0 col4" >Crafts</th>
#       <th id="T_8f3ca_level0_col5" class="col_heading level0 col5" >Physical Education</th>
#       <th id="T_8f3ca_level0_col6" class="col_heading level0 col6" >Grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f3ca_level0_row0" class="row_heading level0 row0" >Mathematics</th>
#       <td id="T_8f3ca_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8f3ca_row0_col1" class="data row0 col1" >0.003702</td>
#       <td id="T_8f3ca_row0_col2" class="data row0 col2" >0.027427</td>
#       <td id="T_8f3ca_row0_col3" class="data row0 col3" >0.022141</td>
#       <td id="T_8f3ca_row0_col4" class="data row0 col4" >0.020291</td>
#       <td id="T_8f3ca_row0_col5" class="data row0 col5" >0.009407</td>
#       <td id="T_8f3ca_row0_col6" class="data row0 col6" >0.013899</td>
#     </tr>
#     <tr>
#       <th id="T_8f3ca_level0_row1" class="row_heading level0 row1" >Physics</th>
#       <td id="T_8f3ca_row1_col0" class="data row1 col0" >0.003702</td>
#       <td id="T_8f3ca_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8f3ca_row1_col2" class="data row1 col2" >-0.022546</td>
#       <td id="T_8f3ca_row1_col3" class="data row1 col3" >-0.012533</td>
#       <td id="T_8f3ca_row1_col4" class="data row1 col4" >-0.001059</td>
#       <td id="T_8f3ca_row1_col5" class="data row1 col5" >-0.006860</td>
#       <td id="T_8f3ca_row1_col6" class="data row1 col6" >0.063921</td>
#     </tr>
#     <tr>
#       <th id="T_8f3ca_level0_row2" class="row_heading level0 row2" >Chemistry</th>
#       <td id="T_8f3ca_row2_col0" class="data row2 col0" >0.027427</td>
#       <td id="T_8f3ca_row2_col1" class="data row2 col1" >-0.022546</td>
#       <td id="T_8f3ca_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8f3ca_row2_col3" class="data row2 col3" >0.015337</td>
#       <td id="T_8f3ca_row2_col4" class="data row2 col4" >-0.031169</td>
#       <td id="T_8f3ca_row2_col5" class="data row2 col5" >0.028189</td>
#       <td id="T_8f3ca_row2_col6" class="data row2 col6" >0.010378</td>
#     </tr>
#     <tr>
#       <th id="T_8f3ca_level0_row3" class="row_heading level0 row3" >Computer Science</th>
#       <td id="T_8f3ca_row3_col0" class="data row3 col0" >0.022141</td>
#       <td id="T_8f3ca_row3_col1" class="data row3 col1" >-0.012533</td>
#       <td id="T_8f3ca_row3_col2" class="data row3 col2" >0.015337</td>
#       <td id="T_8f3ca_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8f3ca_row3_col4" class="data row3 col4" >-0.011109</td>
#       <td id="T_8f3ca_row3_col5" class="data row3 col5" >-0.016266</td>
#       <td id="T_8f3ca_row3_col6" class="data row3 col6" >-0.025750</td>
#     </tr>
#     <tr>
#       <th id="T_8f3ca_level0_row4" class="row_heading level0 row4" >Crafts</th>
#       <td id="T_8f3ca_row4_col0" class="data row4 col0" >0.020291</td>
#       <td id="T_8f3ca_row4_col1" class="data row4 col1" >-0.001059</td>
#       <td id="T_8f3ca_row4_col2" class="data row4 col2" >-0.031169</td>
#       <td id="T_8f3ca_row4_col3" class="data row4 col3" >-0.011109</td>
#       <td id="T_8f3ca_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_8f3ca_row4_col5" class="data row4 col5" >-0.019106</td>
#       <td id="T_8f3ca_row4_col6" class="data row4 col6" >0.026835</td>
#     </tr>
#     <tr>
#       <th id="T_8f3ca_level0_row5" class="row_heading level0 row5" >Physical Education</th>
#       <td id="T_8f3ca_row5_col0" class="data row5 col0" >0.009407</td>
#       <td id="T_8f3ca_row5_col1" class="data row5 col1" >-0.006860</td>
#       <td id="T_8f3ca_row5_col2" class="data row5 col2" >0.028189</td>
#       <td id="T_8f3ca_row5_col3" class="data row5 col3" >-0.016266</td>
#       <td id="T_8f3ca_row5_col4" class="data row5 col4" >-0.019106</td>
#       <td id="T_8f3ca_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_8f3ca_row5_col6" class="data row5 col6" >-0.033313</td>
#     </tr>
#     <tr>
#       <th id="T_8f3ca_level0_row6" class="row_heading level0 row6" >Grade</th>
#       <td id="T_8f3ca_row6_col0" class="data row6 col0" >0.013899</td>
#       <td id="T_8f3ca_row6_col1" class="data row6 col1" >0.063921</td>
#       <td id="T_8f3ca_row6_col2" class="data row6 col2" >0.010378</td>
#       <td id="T_8f3ca_row6_col3" class="data row6 col3" >-0.025750</td>
#       <td id="T_8f3ca_row6_col4" class="data row6 col4" >0.026835</td>
#       <td id="T_8f3ca_row6_col5" class="data row6 col5" >-0.033313</td>
#       <td id="T_8f3ca_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Physics, Crafts, Mathematics

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(random_state=13)
rfr.fit(X_train, y_train)

feature_importances = rfr.feature_importances_

feature_importance_df = pd.DataFrame({'subjects': X_train.columns, 'importance': feature_importances})

feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

top_features = feature_importance_df.head(3)
print(top_features)
# Out:
#            subjects  importance
# 0       Mathematics    0.173139
# 4            Crafts    0.168097
# 3  Computer Science    0.167477

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(df[['Mathematics', 'Crafts', 'Physics']], df.Grade, test_size=0.2, random_state=13)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(df[['Mathematics', 'Crafts', 'Computer Science']], df.Grade, test_size=0.2, random_state=13)

# %% [markdown]
# # Обучение моделей

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
cbc1 = CatBoostClassifier(iterations=100, depth=4, learning_rate=0.1)
cbc1.fit(X_train1, y_train1, silent=True)

y_pred1 = cbc1.predict(X_test1)

accuracy = accuracy_score(y_test1, y_pred1)
precision = precision_score(y_test1, y_pred1, average=None)
recall = recall_score(y_test1, y_pred1, average=None)
f1 = f1_score(y_test1, y_pred1, average=None)
conf_matrix = confusion_matrix(y_test1, y_pred1)

print(f'Accuracy: {accuracy*100:.2f}%')
print(f'Precision: {precision*100}%')
print(f'Recall: {recall*100}%')
print(f'F1-score: {f1*100}%')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Accuracy: 34.41%
# Precision: [33.67875648 38.         32.40740741]%
# Recall: [48.87218045 26.20689655 28.45528455]%
# F1-score: [39.87730061 31.02040816 30.3030303 ]%
# Confusion Matrix:
# [[65 36 32]
#  [66 38 41]
#  [62 26 35]]

# %%
def predict_student_grade(model, subject_scores):
    """
    Predicts the grade of a student based on their scores in 6 subjects.

    Parameters:
    - model: A trained CatBoostClassifier model.
    - subject_scores: A list of 6 scores for the subjects in the following order:
        [Mathematics, Crafts, Physics, Chemistry, Computer Science, Physical Education]

    Returns:
    - predicted_grade: The predicted grade for the student.
    """
    student_data = pd.DataFrame([subject_scores], columns=['Mathematics', 'Crafts', 'Physics', 'Chemistry', 'Computer Science', 'Physical Education'])

    predicted_grade = model.predict(student_data)[0]

    predicted_grade = le.inverse_transform([predicted_grade])[0]

    return predicted_grade

# %%
student_scores = [0, 0, 0, 0, 0, 0]
predicted_student_grade = predict_student_grade(cbc1, student_scores)
print("Predicted Grade:", predicted_student_grade)
# Out:
# Predicted Grade: Good
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:155: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model_filename = "catboost_model.cbm"
cbc1.save_model(model_filename)

# %%
cbc2 = CatBoostClassifier(iterations=100, depth=4, learning_rate=0.1)
cbc2.fit(X_train2, y_train2, silent=True)

y_pred2 = cbc2.predict(X_test2)

accuracy2 = accuracy_score(y_test2, y_pred2)
precision2 = precision_score(y_test2, y_pred2, average=None)
recall2 = recall_score(y_test2, y_pred2, average=None)
f1_2 = f1_score(y_test2, y_pred2, average=None)
conf_matrix2 = confusion_matrix(y_test2, y_pred2)

print(f'Accuracy: {accuracy2*100:.2f}%')
print(f'Precision: {precision2*100}%')
print(f'Recall: {recall2*100}%')
print(f'F1-score: {f1_2*100}%')
print('Confusion Matrix:')
print(conf_matrix2)
# Out:
# Accuracy: 33.17%
# Precision: [32.33532934 37.19008264 30.08849558]%
# Recall: [40.60150376 31.03448276 27.64227642]%
# F1-score: [36.         33.83458647 28.81355932]%
# Confusion Matrix:
# [[54 42 37]
#  [58 45 42]
#  [55 34 34]]

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(X_train1, label=y_train1)
dtest = xgb.DMatrix(X_test1, label=y_test1)

# %%
param = {
    'max_depth': 3,
    'eta': 0.1,
    'num_class': 3
}
num_round = 100
clf = xgb.train(param, dtrain, num_round)

# %%
y_pred3 = clf.predict(dtest)
score = accuracy_score(y_test1, y_pred3)

print(f'Accurecy: {score*100:.2f}%')
# Out:
# Accurecy: 36.16%
