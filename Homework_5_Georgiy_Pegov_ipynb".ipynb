# %% [markdown]
# <a href="https://colab.research.google.com/github/GeorgiyPegov/learning-2023/blob/main/Homework_5_Georgiy_Pegov_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# pd.read_csv('/content/drive/MyDrive/Datasets/Titanic-Dataset.csv')

# %%
url = 'https://drive.google.com/file/d/1ljBzOxmiLTqMZDljbzL3q0U9lOANhk0G/view?usp=sharing'
dataset_url='https://drive.google.com/uc?id=' + url.split('/')[-2]

# %%
pd.read_csv(dataset_url)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df = pd.read_csv(dataset_url)

# %%
# df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %% [markdown]
# Для определения оптимальной логики замещения данных необходимо вывести количество пустых ячеек по столбцам.

# %%
print ('empty cells total -',df.isna().sum().sum(),'\n',df.isna().sum())
# Out:
# empty cells total - 866
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Cabin.unique()
# Out:
# array(['UCabin', 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# Вывод: пустые ячейки Age - добавляем средние значения, Cabin - замещение пустых ячеек на уникальное значение (оригинальные номера кают необходимо оставить, т.к. они являются в т.ч. данными по расположеню кают на корабле, что является ценной информацией), Embarked - заменяем на наиболее частое значение столбца, т.к. его влияние на анализ данных не существенно.

# %%
df.Age[df.Age.isna()] = df.Age.mean()
# Out:
# <ipython-input-151-86820ac969ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Age[df.Age.isna()] = df.Age.mean()

# %%
df[df.Cabin == 'UCabin']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# Проверка значения UCabin на ункальность

# %%
df.Cabin[df.Cabin.isna()] = 'UCabin'
# Out:
# <ipython-input-153-b6c09e022bc4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Cabin[df.Cabin.isna()] = 'UCabin'

# %%
df.Embarked[df.Embarked.isna()] = 'S'
# Out:
# <ipython-input-154-ad9999733c57>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Embarked[df.Embarked.isna()] = 'S'

# %%
print ('empty cells total -',df.isnull().sum().sum(),'\n',df.isnull().sum())
# Out:
# empty cells total - 0
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# Проверка замещения пустых ячеек

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Аналитика по df

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          148
# Embarked         3
# dtype: int64

# %% [markdown]
# Количество уникальных значений

# %% [markdown]
# # Аналитика

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfa = df.copy()

# %%
dfa.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dfa.loc[:, 'Sex'] = dfa['Sex'].astype('category').cat.codes
dfa.loc[:, 'Cabin'] = dfa['Cabin'].astype('category').cat.codes
dfa.loc[:, 'Embarked'] = dfa['Embarked'].astype('category').cat.codes
# Out:
# <ipython-input-231-b4854f6f18b1>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfa.loc[:, 'Sex'] = dfa['Sex'].astype('category').cat.codes
# <ipython-input-231-b4854f6f18b1>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfa.loc[:, 'Cabin'] = dfa['Cabin'].astype('category').cat.codes
# <ipython-input-231-b4854f6f18b1>:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfa.loc[:, 'Embarked'] = dfa['Embarked'].astype('category').cat.codes

# %%
dfa.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Cabin  Embarked
# 0         A/5 21171   7.2500    147         2
# 1          PC 17599  71.2833     81         0
# 2  STON/O2. 3101282   7.9250    147         2
# 3            113803  53.1000     55         2
# 4            373450   8.0500    147         2

# %%
dfa2 = dfa.drop(columns=['PassengerId'])

# %%
dfa2.corr().style.background_gradient(cmap="hot_r")
# Out:
# <ipython-input-247-0fc97abfaae8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfa2.corr().style.background_gradient(cmap="hot_r")
# <style type="text/css">
# #T_f87d7_row0_col0, #T_f87d7_row1_col1, #T_f87d7_row2_col2, #T_f87d7_row3_col3, #T_f87d7_row4_col4, #T_f87d7_row5_col5, #T_f87d7_row6_col6, #T_f87d7_row7_col7, #T_f87d7_row8_col8 {
#   background-color: #0b0000;
#   color: #f1f1f1;
# }
# #T_f87d7_row0_col1 {
#   background-color: #ffff79;
#   color: #000000;
# }
# #T_f87d7_row0_col2, #T_f87d7_row1_col3, #T_f87d7_row1_col6, #T_f87d7_row2_col0, #T_f87d7_row2_col5, #T_f87d7_row3_col4, #T_f87d7_row6_col1, #T_f87d7_row6_col7, #T_f87d7_row6_col8 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_f87d7_row0_col3 {
#   background-color: #ffff3a;
#   color: #000000;
# }
# #T_f87d7_row0_col4 {
#   background-color: #ffff61;
#   color: #000000;
# }
# #T_f87d7_row0_col5 {
#   background-color: #fff900;
#   color: #000000;
# }
# #T_f87d7_row0_col6 {
#   background-color: #ff4c00;
#   color: #f1f1f1;
# }
# #T_f87d7_row0_col7 {
#   background-color: #ffff5a;
#   color: #000000;
# }
# #T_f87d7_row0_col8 {
#   background-color: #ffffd4;
#   color: #000000;
# }
# #T_f87d7_row1_col0 {
#   background-color: #ffff7d;
#   color: #000000;
# }
# #T_f87d7_row1_col2, #T_f87d7_row2_col1 {
#   background-color: #ff8300;
#   color: #f1f1f1;
# }
# #T_f87d7_row1_col4 {
#   background-color: #fffe00;
#   color: #000000;
# }
# #T_f87d7_row1_col5 {
#   background-color: #ffff2a;
#   color: #000000;
# }
# #T_f87d7_row1_col7 {
#   background-color: #960000;
#   color: #f1f1f1;
# }
# #T_f87d7_row1_col8, #T_f87d7_row5_col7 {
#   background-color: #ffd700;
#   color: #000000;
# }
# #T_f87d7_row2_col3 {
#   background-color: #ffda00;
#   color: #000000;
# }
# #T_f87d7_row2_col4 {
#   background-color: #ffffa0;
#   color: #000000;
# }
# #T_f87d7_row2_col6 {
#   background-color: #ffff13;
#   color: #000000;
# }
# #T_f87d7_row2_col7 {
#   background-color: #ff9d00;
#   color: #000000;
# }
# #T_f87d7_row2_col8 {
#   background-color: #fff400;
#   color: #000000;
# }
# #T_f87d7_row3_col0 {
#   background-color: #ffdc00;
#   color: #000000;
# }
# #T_f87d7_row3_col1 {
#   background-color: #ffff71;
#   color: #000000;
# }
# #T_f87d7_row3_col2, #T_f87d7_row4_col1 {
#   background-color: #ff9800;
#   color: #000000;
# }
# #T_f87d7_row3_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_f87d7_row3_col6 {
#   background-color: #ff9500;
#   color: #000000;
# }
# #T_f87d7_row3_col7 {
#   background-color: #ffff4e;
#   color: #000000;
# }
# #T_f87d7_row3_col8 {
#   background-color: #ffff5e;
#   color: #000000;
# }
# #T_f87d7_row4_col0 {
#   background-color: #ffcc00;
#   color: #000000;
# }
# #T_f87d7_row4_col2 {
#   background-color: #ffef00;
#   color: #000000;
# }
# #T_f87d7_row4_col3, #T_f87d7_row7_col3 {
#   background-color: #ffffb8;
#   color: #000000;
# }
# #T_f87d7_row4_col5 {
#   background-color: #ff4700;
#   color: #f1f1f1;
# }
# #T_f87d7_row4_col6, #T_f87d7_row8_col1 {
#   background-color: #ff7600;
#   color: #f1f1f1;
# }
# #T_f87d7_row4_col7, #T_f87d7_row5_col1 {
#   background-color: #ffb500;
#   color: #000000;
# }
# #T_f87d7_row4_col8 {
#   background-color: #ffff0f;
#   color: #000000;
# }
# #T_f87d7_row5_col0 {
#   background-color: #ff9b00;
#   color: #000000;
# }
# #T_f87d7_row5_col2 {
#   background-color: #ffff3e;
#   color: #000000;
# }
# #T_f87d7_row5_col3 {
#   background-color: #ffff8d;
#   color: #000000;
# }
# #T_f87d7_row5_col4 {
#   background-color: #ff4900;
#   color: #f1f1f1;
# }
# #T_f87d7_row5_col6 {
#   background-color: #ff5e00;
#   color: #f1f1f1;
# }
# #T_f87d7_row5_col8 {
#   background-color: #ffff26;
#   color: #000000;
# }
# #T_f87d7_row6_col0 {
#   background-color: #ff4f00;
#   color: #f1f1f1;
# }
# #T_f87d7_row6_col2 {
#   background-color: #ffff17;
#   color: #000000;
# }
# #T_f87d7_row6_col3, #T_f87d7_row6_col4 {
#   background-color: #ffd400;
#   color: #000000;
# }
# #T_f87d7_row6_col5 {
#   background-color: #ffb200;
#   color: #000000;
# }
# #T_f87d7_row7_col0 {
#   background-color: #ffff46;
#   color: #000000;
# }
# #T_f87d7_row7_col1 {
#   background-color: #930000;
#   color: #f1f1f1;
# }
# #T_f87d7_row7_col2 {
#   background-color: #ff9300;
#   color: #000000;
# }
# #T_f87d7_row7_col4 {
#   background-color: #ffff1f;
#   color: #000000;
# }
# #T_f87d7_row7_col5 {
#   background-color: #ffff52;
#   color: #000000;
# }
# #T_f87d7_row7_col6 {
#   background-color: #ffffe3;
#   color: #000000;
# }
# #T_f87d7_row7_col8 {
#   background-color: #ffbf00;
#   color: #000000;
# }
# #T_f87d7_row8_col0, #T_f87d7_row8_col4 {
#   background-color: #ffff0b;
#   color: #000000;
# }
# #T_f87d7_row8_col2 {
#   background-color: #ff8e00;
#   color: #f1f1f1;
# }
# #T_f87d7_row8_col3, #T_f87d7_row8_col5 {
#   background-color: #ffff1b;
#   color: #000000;
# }
# #T_f87d7_row8_col6 {
#   background-color: #ffff2e;
#   color: #000000;
# }
# #T_f87d7_row8_col7 {
#   background-color: #ff6e00;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f87d7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f87d7_level0_col0" class="col_heading level0 col0" >Survived</th>
#       <th id="T_f87d7_level0_col1" class="col_heading level0 col1" >Pclass</th>
#       <th id="T_f87d7_level0_col2" class="col_heading level0 col2" >Sex</th>
#       <th id="T_f87d7_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_f87d7_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_f87d7_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_f87d7_level0_col6" class="col_heading level0 col6" >Fare</th>
#       <th id="T_f87d7_level0_col7" class="col_heading level0 col7" >Cabin</th>
#       <th id="T_f87d7_level0_col8" class="col_heading level0 col8" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f87d7_level0_row0" class="row_heading level0 row0" >Survived</th>
#       <td id="T_f87d7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f87d7_row0_col1" class="data row0 col1" >-0.338481</td>
#       <td id="T_f87d7_row0_col2" class="data row0 col2" >-0.543351</td>
#       <td id="T_f87d7_row0_col3" class="data row0 col3" >-0.069809</td>
#       <td id="T_f87d7_row0_col4" class="data row0 col4" >-0.035322</td>
#       <td id="T_f87d7_row0_col5" class="data row0 col5" >0.081629</td>
#       <td id="T_f87d7_row0_col6" class="data row0 col6" >0.257307</td>
#       <td id="T_f87d7_row0_col7" class="data row0 col7" >-0.254888</td>
#       <td id="T_f87d7_row0_col8" class="data row0 col8" >-0.167675</td>
#     </tr>
#     <tr>
#       <th id="T_f87d7_level0_row1" class="row_heading level0 row1" >Pclass</th>
#       <td id="T_f87d7_row1_col0" class="data row1 col0" >-0.338481</td>
#       <td id="T_f87d7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f87d7_row1_col2" class="data row1 col2" >0.131900</td>
#       <td id="T_f87d7_row1_col3" class="data row1 col3" >-0.331339</td>
#       <td id="T_f87d7_row1_col4" class="data row1 col4" >0.083081</td>
#       <td id="T_f87d7_row1_col5" class="data row1 col5" >0.018443</td>
#       <td id="T_f87d7_row1_col6" class="data row1 col6" >-0.549500</td>
#       <td id="T_f87d7_row1_col7" class="data row1 col7" >0.684121</td>
#       <td id="T_f87d7_row1_col8" class="data row1 col8" >0.162098</td>
#     </tr>
#     <tr>
#       <th id="T_f87d7_level0_row2" class="row_heading level0 row2" >Sex</th>
#       <td id="T_f87d7_row2_col0" class="data row2 col0" >-0.543351</td>
#       <td id="T_f87d7_row2_col1" class="data row2 col1" >0.131900</td>
#       <td id="T_f87d7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f87d7_row2_col3" class="data row2 col3" >0.084153</td>
#       <td id="T_f87d7_row2_col4" class="data row2 col4" >-0.114631</td>
#       <td id="T_f87d7_row2_col5" class="data row2 col5" >-0.245489</td>
#       <td id="T_f87d7_row2_col6" class="data row2 col6" >-0.182333</td>
#       <td id="T_f87d7_row2_col7" class="data row2 col7" >0.096681</td>
#       <td id="T_f87d7_row2_col8" class="data row2 col8" >0.108262</td>
#     </tr>
#     <tr>
#       <th id="T_f87d7_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_f87d7_row3_col0" class="data row3 col0" >-0.069809</td>
#       <td id="T_f87d7_row3_col1" class="data row3 col1" >-0.331339</td>
#       <td id="T_f87d7_row3_col2" class="data row3 col2" >0.084153</td>
#       <td id="T_f87d7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f87d7_row3_col4" class="data row3 col4" >-0.232625</td>
#       <td id="T_f87d7_row3_col5

# %% [markdown]
# Наибольшее влияние на признак Survived имеет признак Fare
